# %% [markdown]
# # Train Student Final Score Prediction Model
# This notebook demonstrates dataset loading, feature scaling, training Linear Regression & Random Forest models, evaluating metrics (MAE, RMSE, R2), and exporting the trained model artifact.

# %%
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, r2_score

# Load dataset
df = pd.read_csv('../data/raw/student_data.csv')
df.head()
